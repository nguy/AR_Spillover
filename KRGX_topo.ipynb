# %%
import pandas as pd

from pyradarmet.BeamBlock import BeamBlock

# %matplotlib inline
# Out:
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119
# /Users/guy/anaconda/lib/python2.7/site-packages/ipykernel/pylab/config.py:66: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   inline backend."""
# /Users/guy/anaconda/lib/python2.7/site-packages/ipykernel/pylab/config.py:71: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
# ...

# %%
nexs = pd.read_table('/Users/guy/Documents/Reference/Radar/nexrad-stations.txt',header = 0, 
                     sep = "\s+|\t+|\s+\t+|\t+\s+")
# Out:
# /Users/guy/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-934481ee497b> in <module>()
#       1 nexs = pd.read_table('/Users/guy/Documents/Reference/Radar/nexrad-stations.txt',header = 0,
# ----> 2                      sep = "\s+|\t+|\s+\t+|\t+\s+")
#
# ...

# %%
block_KRGX = BeamBlock(radar_lon=-119.46111, radar_lat=39.75417, radar_antenna_height=25., 
               elev_angle=0.9, beamwidth=1., 
               range_dist=250., azimuthal_angle=235.)

# %%
block_KRGX.plot_3panel(beam_blockage='complete', lon_plot_range=2., lat_plot_range=2.,
                       terrain_cmap=None, beam_blockage_cmap=None,
                       range_rings=(25., 50., 75., 100.), saveFig=False)
# Out:
# /Users/guy/anaconda/lib/python2.7/site-packages/numpy/ma/core.py:3117: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   dout = self.data[indx]
# /Users/guy/anaconda/lib/python2.7/site-packages/pyradarmet-0.1.3-py2.7.egg/pyradarmet/BeamBlock.py:771: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   bbf, = axb.plot(self.rng_gnd / 1000., self.CBB[self.Az_plot, :], '-k',
# /Users/guy/anaconda/lib/python2.7/site-packages/IPython/core/formatters.py:92: DeprecationWarning: DisplayFormatter._ipython_display_formatter_default is deprecated: use @default decorator instead.
#   def _ipython_display_formatter_default(self):
# /Users/guy/anaconda/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):

# %% [markdown]
# __Can run once to create the file to use in the Hovmoeller plots.__

# %%
block_KRGX.save_map_data(filename='KRGX_block_terrain')
# Out:
# Saving KRGX_block_terrain.nc.nc
